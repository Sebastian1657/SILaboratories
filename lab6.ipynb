# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
import ollama

# %%
message = "Tell me something about transformer technology"
response = ollama.chat(model='llama3.2', messages=[{'role': 'user', 'content': message}])
print(response['message']['content'])
# Out:
# Transformer technology has revolutionized the way we distribute and use electricity. Here's a brief overview:
#
# **What is a Transformer?**
#
# A transformer is an electrical device that transfers electrical energy from one circuit to another through electromagnetic induction. It consists of two or more coils of wire, known as primary and secondary coils, which are wound around a common core.
#
# **How does it work?**
#
# When an alternating current (AC) flows through the primary coil, it generates a magnetic field. This magnetic field induces a voltage in the secondary coil, causing a current to flow. The transformer can step up or step down the voltage of the electrical signal, making it suitable for various applications.
#
# **Key Components and Types:**
#
# 1. **Primary Coil**: Receives the input voltage from the power source.
# 2. **Secondary Coil**: Transfers the output voltage to the load.
# ...

# %%
# Niektóre strony internetowe wymagają użycia odpowiednich nagłówków podczas ich pobierania:
headers = {
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}
# Klasa reprezentująca stronę internetową, która zostanie pobrana do podsumowania.
class Website:
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        # Użyjemy biblioteki BeautifulSoup do zbudowania obiektu z treścią
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input","link"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
web = Website("https://pl.wikipedia.org/wiki/Du%C5%BCy_model_j%C4%99zykowy")
print("Title: ", web.title)
print("Text: ", web.text)
# Out:
# Title:  Duży model językowy – Wikipedia, wolna encyklopedia
# Text:  Przejdź do zawartości
# Menu główne
# Menu główne
# przypnij
# ukryj
# Nawigacja
# Strona główna
# Losuj artykuł
# Kategorie artykułów
# Najlepsze artykuły
# Częste pytania (FAQ)
# Dla czytelników
# O Wikipedii
# Kontakt
# Dla wikipedystów
# Pierwsze kroki
# Portal wikipedystów
# Ogłoszenia
# Zasady
# Pomoc
# Strony specjalne
# Ostatnie zmiany
# Szukaj
# Szukaj
# Wygląd
# Wspomóż Wikipedię
# Utwórz konto
# Zaloguj się
# Narzędzia osobiste
# Wspomóż Wikipedię
# Utwórz konto
# Zaloguj się
# Spis treści
# przypnij
# ukryj
# Początek
# 1
# Historia
# 2
# Trenowanie i architektura
# Przełącz podsekcję Trenowanie i architektura
# 2.1
# Wzmacnianie z informacją zwrotną od człowieka
# 2.2
# Mieszanka ekspertów
# 2.3
# Dostrajanie na podstawie instrukcji
# 3
# Koszt
# 4
# Rozumowanie
# 5
# Oddziaływanie
# Przełącz podsekcję Oddziaływanie
# 5.1
# Prawa autorskie
# 5.2
# Bezpieczeństwo
# 5.3
# Stronniczość algorytmiczna
# 5.4
# ...

# %%
system_prompt = "Jesteś asystentem, który analizuje zawartość strony internetowej \
i dostarcza krótkie podsumowanie, ignorując tekst, który może być związany z nawigacją. \
Odpowiadaj w formacie markdown w języku polskim."

# %%
def user_prompt_for(website):
    user_prompt = f"Przeglądasz stronę internetową zatytułowaną {website.title}"
    user_prompt += f"\nZawartość tej strony jest następująca; przygotuj podsumowanie tej strony w formacie markdown. Podsumuj również wiadomości i ogłoszenia. Nie dopytuj o szczegóły, bezpośrednio przejdź do wykonywania prompta. Upewnij się, że odpowiedź jest w 100% w języku polskim.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
messages_for(web)
# Out:
# [{'role': 'system',
#   'content': 'Jesteś asystentem, który analizuje zawartość strony internetowej i dostarcza krótkie podsumowanie, ignorując tekst, który może być związany z nawigacją. Odpowiadaj w formacie markdown w języku polskim.'},
#  {'role': 'user',
# ...

# %%
MODEL = 'llama3.2'
def summarize(url):
    website = Website(url)
    response = ollama.chat(model=MODEL, messages=messages_for(website))
    return response['message']['content']

# %%
summarize("https://wp.pl")
# Out:
# '"Świat jest pełen cudownych rozkładów i kolorowych kompozycji, które z regułę nie są w stanie być zaimplementowane w naszych codziennych życiach."'

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://wp.pl")
# Out:
# Jasne, oto lista 10 najnowszych artykułów z naszego portalu WP.pl:
#
# 1.   Wyspa Kocka:  Oto czasy otwarcia na ten sezon. Pobierz bilet na stronie oficjalnej
# 2.  Nowy samolot Boeing 787-8 Air Berlin. Jak wygląda nowożytne przęsło w niemieckich portach lotniczych?
# 3.   Przypadek z Tarczynem:  Kiedy widać "czarownicę" na drodze? Zobacz, ile razy spotykali ją mieszkańcy.
# 4.   Nowy skarb pieniędzy. Oto trzysta i czternaście razy więcej pieniędzy w Twoich rękach
# 5.  Kolejka na przekroczenie granicy polsko-rosyjskiej. To, o co my się nie śniemy.
# 6.   Kto jest w szkodzie? Wizja pożarstwa Kocięży w okolicy Kolejowa Most.
# 7.  Jak powinien wyglądać pałac na Wyspie Kockiej?
# 8.  Skandalowe zdjęcia z przemysłu motorycznego
# 9.   To, co cię zaburza na workach? Wydaj się, że to nie twoja wola, ale...
# 10. Co myślisz o politykach? Oto listy i statystyki po wyborach.

# %%
# MODEL = 'deepseek-r1:1.5b'
MODEL = 'qwen3:4b'
display_summary("https://wp.pl")
# Out:
# The text you provided appears to be content from the Polish news and entertainment website **Wirtualna Polska Media S.A.** (Virtual Poland Media). It includes articles, quizzes, videos, advertisements, and legal disclaimers typical of such platforms.
#
# If you have a specific question or need help with something related to this content (e.g., translation, summarization, analysis, or clarification), please let me know! For example:
# - Would you like me to translate a specific section into English?
# - Are you looking for information about a particular article or topic?
# - Do you need help understanding the legal disclaimer or terms?
#
# Let me know how I can assist! 😊
